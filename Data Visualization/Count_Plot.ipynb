# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
catergories = ['A','B','A','C','B','A','C','C','B','A']
sns.countplot(x=catergories)
plt.title("Count plot Example")

plt.xlabel("Category")
plt.ylabel("Count")
plt.show()
